# %% [markdown]
# **DATA ANALYSIS ON A BICYCLE DATASET**

# %% [markdown]
# IMPORT ALL THE REQUIRED MODULES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# IMPORT THE DATASET

# %%
bicycle = pd.read_csv('//Users/da_learners_m1_18/Downloads/das223 2/Regression/day.csv')

# %% [markdown]
# SHOWING THE STRUCTURE OF THE DATASET

# %%
bicycle.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# 1. On this datase, we have 16 columns described as follows:
# * Instant- unique identifier for each observation in the dataset.
# * dteday- date + timestamp.
# * season-  1 = spring, 2 = summer, 3 = fall, 4 = winter.
# * yr- ehther its 2018 or 2019.
# * mnth- The month for which the observation was recorded.
# * holiday- whether the day is considered a holiday.
# * weekday- whether the day is neither a weekend nor holiday.
# * workingday- whether the day is neither a weekend nor holiday.
# * atemp- feels like" temperature in Celsius.
# * hum- relative humidity.
# * windspeed- wind speed.
# * weathersit- 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog.
# * temp- temperature in Celsius.
# * casual- number of non-registered user rentals initiated.
# * registered- number of registered user rentals initiated.
# * cnt- number of total rentals (Dependent Variable).

# %% [markdown]
# CANGING THE NAMES OF THE VALUES IN THE DATASET FROM THE NUMBERS TO NAMES

# %%
bicycle['yr'] = bicycle['yr'].map({0:2018, 1:2019})
bicycle['season']= bicycle ['season'].map({1:'Spring', 2:'Summer', 3:'Fall', 4:'Winter'})
bicycle['weekday']= bicycle ['weekday'].map({0:'Tuesday', 1:'Wednesday', 2:'Thursday', 3:'Friday', 4:'Saturday', 5:'Sunday', 6:'Monday'})
bicycle['holiday'] = bicycle['holiday'].map({0:'No', 1:'Yes'})
bicycle['workingday'] = bicycle['workingday'].map({0:'No', 1:'Yes'})

# %%
bicycle.head()
# Out:
#    instant      dteday  season    yr  mnth holiday    weekday workingday  \
# 0        1  01-01-2018  Spring  2018     1      No     Monday         No
# 1        2  02-01-2018  Spring  2018     1      No    Tuesday         No
# 2        3  03-01-2018  Spring  2018     1      No  Wednesday        Yes
# 3        4  04-01-2018  Spring  2018     1      No   Thursday        Yes
# 4        5  05-01-2018  Spring  2018     1      No     Friday        Yes
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# **DATA CLEANING PROCESS**

# %% [markdown]
# CHECK IF THERE IS NULL VALUES.

# %%
bicycle.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# CHECK IF THERE ARE DUPLICATES

# %%
bicycle.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **DATA ANALYSIS**

# %% [markdown]
# STATISTICAL SUMMARY OF THE DATASET

# %%
bicycle.describe()
# Out:
#           instant           yr        mnth  weathersit        temp  \
# count  730.000000   730.000000  730.000000  730.000000  730.000000
# mean   365.500000  2018.500000    6.526027    1.394521   20.319259
# std    210.877136     0.500343    3.450215    0.544807    7.506729
# min      1.000000  2018.000000    1.000000    1.000000    2.424346
# 25%    183.250000  2018.000000    4.000000    1.000000   13.811885
# 50%    365.500000  2018.500000    7.000000    1.000000   20.465826
# 75%    547.750000  2019.000000   10.000000    2.000000   26.880615
# max    730.000000  2019.000000   12.000000    3.000000   35.328347
#
#             atemp         hum   windspeed       casual   registered  \
# count  730.000000  730.000000  730.000000   730.000000   730.000000
# mean    23.726322   62.765175   12.763620   849.249315  3658.757534
# std      8.150308   14.237589    5.195841   686.479875  1559.758728
# min      3.953480    0.000000    1.500244     2.000000    20.000000
# ...

# %% [markdown]
# SUMMARY OF THE DATASET

# %%
bicycle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    object
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    object
#  6   weekday     730 non-null    object
#  7   workingday  730 non-null    object
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 91.4+ KB

# %% [markdown]
# 1.WHAT IS THE TOTAL NUMBER OF BIKE RENTALS IN EACH SEASON OVER THE 2 YEAR PERIOD?

# %%
sns.barplot(x='season', y='cnt', data=bicycle)
plt.show()

# %% [markdown]
# 2.WHAT IS THE TOTAL NUMBER OF BIKE RENTALS BY SEASON FOR THE YEAR 2018?

# %%
year_2018_bikes = bicycle[bicycle['yr'] == 2018]
year_2018_by_month = year_2018_bikes.groupby(['season'])['cnt'].sum()
print(year_2018_by_month)
year_2018_by_month.plot(kind='bar')
plt.xlabel('season')
plt.ylabel('Bike Count')
plt.title('Bike Rentals by season for year 2018')
plt.show()
# Out:
# season
# Fall      419650
# Spring    150000
# Summer    347316
# Winter    326137
# Name: cnt, dtype: int64

# %% [markdown]
# 3.WHAT IS THE TOTAL NUMBER OF BIKE RENTALS BY SEASON FOR THE YEAR 2019?

# %%
year_2019_bikes = bicycle[bicycle['yr'] == 2019]
year_2019_by_month = year_2019_bikes.groupby(['season'])['cnt'].sum()
print(year_2019_by_month)
year_2019_by_month.plot(kind='bar')
plt.xlabel('season')
plt.ylabel('Bike Count')
plt.title('Bike Rentals by season for year 2019')
plt.show()
# Out:
# season
# Fall      641479
# Spring    319514
# Summer    571273
# Winter    515476
# Name: cnt, dtype: int64

# %% [markdown]
# 4.WHAT IS THE TOTAL NUMBER OF BIKE RENTALS FOR 2018 AND 2018?

# %%
sns.barplot(x='yr', y='cnt', data=bicycle)
plt.title('Total bike Rentals by year')
plt.show()

# %% [markdown]
# 5.ARE BIKE RENTALS HIGH ON WORKINGDAYS ?

# %%
sns.barplot(x='workingday', y='cnt', data=bicycle)
plt.title('Total bike Rentals by workingday')
plt.show()

# %% [markdown]
# 6.WHICH DAY IS POPULAR?

# %%
sns.barplot(x='weekday', y='cnt', data=bicycle)
plt.title('Bike rentals by weekday')
plt.show()

# %% [markdown]
# 7.WHICH MONTH IS POPULAR?

# %%
sns.barplot(x='mnth', y='cnt', data=bicycle)
plt.title('Bike rentals by month')
plt.show()

# %% [markdown]
# 8.DO PEOPLE PREFER TO RENT BIKES ON HOLIDAYS ?

# %%
sns.barplot(x='holiday', y='cnt', data=bicycle)
plt.title('Bike rentals')
plt.show()

# %% [markdown]
# 9.WHICH WEATHER SITUATION HAS A HIGH  BIKE RENTAL?

# %%
sns.barplot(x='weathersit', y='cnt', data=bicycle)
plt.show()

# %% [markdown]
# 10.HOW IS THE DEMAND DISTRIBUTED?

# %%
plt.figure(figsize=(10, 8))
plt.boxplot(bicycle['cnt'])
plt.show()

# %% [markdown]
# 11.WHAT IS THE DEMAND  DISTRIBUTED FOR THE 2018 AND 2019?

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='yr', y='cnt', data=bicycle)
plt.show()

# %% [markdown]
# 12.WHAT IS THE DEMAND  DISTRIBUTED FOR THE MONTHS?

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='mnth', y='cnt', data=bicycle)
plt.show()

# %% [markdown]
# 13.WHAT IS THE DEMAND DISTRIBUTED FOR THE SEASONS?

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='season', y='cnt', data=bicycle)
plt.show()

# %% [markdown]
# 14.How does the relationship between temperature and bike rentals vary by season?

# %%
sns.scatterplot(x='temp', y='cnt', hue='season', data=bicycle)
plt.show()

# %% [markdown]
# 15.Is there a relationship between windspeed and bike rentals?

# %%
sns.scatterplot(x='windspeed', y='cnt', hue='season', data=bicycle)
plt.show()

# %% [markdown]
# 16.Are there any specific seasons in which bike rentals are higher for a given humidity?

# %%
sns.scatterplot(x='hum', y='cnt', hue='season', data=bicycle)
plt.show()

# %% [markdown]
# 17.Is there a relationship between  atemp  and bike rentals?

# %%
sns.scatterplot(x='atemp', y='cnt', hue='season', data=bicycle)
plt.show()

# %% [markdown]
# SUM OF CASUAL USERS IN 2018 AND 2019 PER MONTH

# %%
bicycle.groupby(['yr','mnth']).sum()['casual']
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/125207543.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['casual']
# yr    mnth
# 2018  1        3073
#       2        6242
#       3       12826
#       4       22346
#       5       31050
#       6       30612
#       7       36452
#       8       28842
#       9       26545
#       10      25222
#       11      15594
#       12       8448
# 2019  1        8969
#       2        8656
#       3       31618
#       4       38456
#       5       44235
#       6       43294
#       7       41705
#       8       43197
#       9       43778
#       10      34538
#       11      21009
#       12      13245
# Name: casual, dtype: int64

# %%
bicycle.groupby(['yr','mnth']).sum()['registered']
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/765599353.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['registered']
# yr    mnth
# 2018  1        35116
#       2        41973
#       3        51219
#       4        72524
#       5       104771
#       6       112900
#       7       104889
#       8       107849
#       9       100873
#       10       98289
#       11       86573
#       12       78875
# 2019  1        87775
#       2        92647
#       3       133257
#       4       135768
#       5       151630
#       6       159536
#       7       161902
#       8       171306
#       9       174795
#       10      164303
#       11      131655
#       12      110468
# Name: registered, dtype: int64

# %% [markdown]
# AVERAGE CASUAL WINDSPEED IN 2018 AND 2019 PER MONTH

# %%
bicycle.groupby(['yr','mnth']).mean()['windspeed']
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/1521948396.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).mean()['windspeed']
# yr    mnth
# 2018  1       13.093060
#       2       15.314059
#       3       15.571321
#       4       16.362499
#       5       12.145379
#       6       11.939090
#       7       11.501716
#       8       12.778276
#       9       10.250290
#       10      11.770932
#       11      12.123370
#       12      11.258681
# 2019  1       14.551511
#       2       13.675088
#       3       14.270404
#       4       15.058121
#       5       12.375138
#       6       12.907177
#       7       10.750167
#       8       10.392756
#       9       11.986356
#       10      11.706602
#       11      12.506020
# ...

# %% [markdown]
# 18.Are there any months or years where windspeed is particularly high or low?

# %%
bicycle.groupby(['yr','mnth']).sum()['windspeed'].plot(kind='line')
plt.xlabel('Year-Month')
plt.ylabel('Number of registered users')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/493458756.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['windspeed'].plot(kind='line')

# %% [markdown]
# 19.Are there any months or years where hum is particularly high or low?

# %%
bicycle.groupby(['yr','mnth']).sum()['hum'].plot(kind='line')
plt.xlabel('Year-Month')
plt.ylabel('Number of registered users')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/534839173.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['hum'].plot(kind='line')

# %% [markdown]
# 20. HOW DOES THE TEMPERATURE CHANGES FROM 2018 TO 2019?

# %%
bicycle.groupby(['yr','mnth']).sum()['temp'].plot(kind='line')
plt.xlabel('Year-Month')
plt.ylabel('Number of registered users')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/3148512998.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['temp'].plot(kind='line')

# %% [markdown]
# 21. HOW DOES THJE ATEMP CHANGES OVER THE 2 YEARS?

# %%
bicycle.groupby(['yr','mnth']).sum()['atemp'].plot(kind='line')
plt.xlabel('Year-Month')
plt.ylabel('Number of registered users')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/320633009.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['atemp'].plot(kind='line')

# %% [markdown]
# 22. HOW DOES WEATHER SITUATION CHANGES ACROSS THE MONTHS?

# %%
bicycle.groupby(['yr','mnth']).sum()['weathersit'].plot(kind='line')
plt.xlabel('Year-Month')
plt.ylabel('Number of registered users')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/2419667941.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['weathersit'].plot(kind='line')

# %% [markdown]
# 23. HOW DOES CASUAL USERS CHANGES ACROSS THE MONTHS?

# %%
bicycle.groupby(['yr','mnth']).sum()['casual'].plot(kind='line')
plt.xlabel('Year-Month')
plt.ylabel('Number of registered users')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/2088766974.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['casual'].plot(kind='line')

# %% [markdown]
# 22. HOW REGISTERED USERS CHANGES ACROSS THE MONTHS?

# %%
bicycle.groupby(['yr','mnth']).sum()['registered'].plot(kind='line')
plt.xlabel('Year-Month')
plt.ylabel('Number of registered users')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/926304788.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['registered'].plot(kind='line')

# %% [markdown]
# 23. HOW DOES THE DEMAND IN BIKE RENTALS CHANGES OVER THE MONTHS?

# %%
bicycle.groupby(['yr','mnth']).sum()['cnt'].plot(kind='line')
plt.xlabel('Year-Month')
plt.ylabel('Number of all users')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/3719671020.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).sum()['cnt'].plot(kind='line')

# %% [markdown]
# 24. THE DISTRIBUTION OF BIKE RENTALS OVER THE 2 YEAR PERIOD?

# %%
bicycle.groupby(['yr','mnth']).mean()['cnt'].plot(kind='bar')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/2276652279.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','mnth']).mean()['cnt'].plot(kind='bar')

# %% [markdown]
# 25. HOW IS BIKE RENTALS DISTRIBUTED OVER THE SEASONS IN THE 2 YEARS PERIOD?

# %%
bicycle.groupby(['yr','season']).mean()['cnt'].plot(kind='bar')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/1419740728.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['yr','season']).mean()['cnt'].plot(kind='bar')

# %% [markdown]
# 26.WHAT IS THE RELATIONSHIP BETWEEN WEATHERSIT AND SAESON OVER THE 2 YEARS?

# %%
bicycle.groupby(['weathersit','season']).mean()['cnt'].plot(kind='bar')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/1342335095.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['weathersit','season']).mean()['cnt'].plot(kind='bar')

# %% [markdown]
# 27. WHAT IS THE RELATIONSHIP BETWEEN WEATHERSIT AND SAESON?

# %%
bicycle.groupby(['season','weathersit']).count()['cnt'].unstack().plot(kind='bar')
plt.xlabel('Season')
plt.ylabel('Bikes Rented(cnt)')
plt.show()

# %% [markdown]
# 28. DISTRIBUTION OF WORKINGDAY

# %%
sns.boxplot(x='workingday', y='cnt', data=bicycle)
plt.xlabel('Working Day')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 29. HOW DOES BIKE RENTALS CHANGE OVER THE SEASON ON WHETHER IT IS A WORKINGDAY OR NOT?

# %%
bicycle.groupby(['workingday','season']).mean()['cnt'].plot(kind='bar')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/3832021378.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['workingday','season']).mean()['cnt'].plot(kind='bar')

# %% [markdown]
# 30. HOW DOES THE BIKE RENTALS CHANGES OVER THE TWO YEARS BASED ON WHETHER IT IS A WORKINGDAY OR NOT?

# %%
bicycle.groupby(['workingday','yr']).mean()['cnt'].plot(kind='bar')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/3295608301.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bicycle.groupby(['workingday','yr']).mean()['cnt'].plot(kind='bar')

# %% [markdown]
# 31. WHAT IS THE CORRELATION OF THE COLUMNS AGAINST THE DEMAND OF BIKE RENTALS?

# %%
plt.figure(figsize=(15,8))
dataplot=sns.heatmap(bicycle.corr(),annot=True,fmt='.2f',cmap='magma')
plt.show()
# Out:
# /var/folders/l_/lp5h3pmn2fs0lh819_gfmp_00000gn/T/ipykernel_3765/2235098655.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot=sns.heatmap(bicycle.corr(),annot=True,fmt='.2f',cmap='magma')

# %% [markdown]
# 32. WHAT IS THE AVERAGE BIKE RENTALS BASED ON THE WEATHER SITUATION?

# %%
# Average values across each of the categorical columns 
fig = plt.figure(figsize=(15, 12))
axes = fig.add_subplot(2, 2, 1)
group_weather = pd.DataFrame(bicycle.groupby(['weathersit'])['cnt'].mean()).reset_index()
sns.barplot(data=group_weather, x='weathersit', y='cnt', ax=axes)
axes.set(xlabel='Weather situation', ylabel='Count', title='Average bike rentals across Weather')
# Out:
# [Text(0.5, 0, 'Weather situation'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Average bike rentals across Weather')]

# %% [markdown]
# 33. WHAT IS THE AVERAGE BIKE RENTALS OVER THE SEASONS?

# %%
fig = plt.figure(figsize=(15, 12))
axes = fig.add_subplot(2, 2, 2)
group_season = pd.DataFrame(bicycle.groupby(['season'])['cnt'].mean()).reset_index()
sns.barplot(data=group_season, x='season', y='cnt', ax=axes)
axes.set(xlabel='Season', ylabel='Count', title='Average bike rentals across Seasons')
# Out:
# [Text(0.5, 0, 'Season'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Average bike rentals across Seasons')]

# %% [markdown]
# 34. WHAT IS THE AVERAGE BIKE RENTALS ON WHETHER IT IS A WORKINGDAY OR NOT?

# %%
fig = plt.figure(figsize=(15, 12))
axes = fig.add_subplot(2, 2, 3)
group_workingday = pd.DataFrame(bicycle.groupby(['workingday'])['cnt'].mean()).reset_index()
sns.barplot(data=group_workingday, x='workingday', y='cnt', ax=axes)
axes.set(xlabel='Working Day', ylabel='Count', title='Average bike rentals on whether its a  Working Day or not?')
# Out:
# [Text(0.5, 0, 'Working Day'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Average bike rentals on whether its a  Working Day or not?')]

# %% [markdown]
# 35. WHAT IS THE AVERAGE BIKE RENTALS ON WHETHER IT IS A HOLIDAY OR NOT?

# %%
fig = plt.figure(figsize=(15, 12))
axes = fig.add_subplot(2, 2, 4)
group_season = pd.DataFrame(bicycle.groupby(['holiday'])['cnt'].mean()).reset_index()
sns.barplot(data=group_season, x='holiday', y='cnt', ax=axes)
axes.set(xlabel='Holiday', ylabel='Count', title='Average bike rentals on whether it is a Holiday or not')
plt.show()
